# %%
from scipy.optimize import differential_evolution
import numpy as np
import json
import matplotlib.pyplot as plt
plt.rcParams["font.family"] = "serif"
plt.style.use('seaborn-deep')
plt.rcParams["font.serif"] = ["Times New Roman"] + plt.rcParams["font.serif"]
# import matplotlib.pyplot as plt
from MSC_osteogenesis import *
# %config Completer.use_jedi = False
showOriginalModelString = True

# %%
study = 'Qiao_2021'
from observations import observations
from calibration_osteogenesis import Plot
plot_obj = Plot(study,observations)
plot_obj.plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-f35861ff6761> in <module>
#       3 from calibration_osteogenesis import Plot
#       4 plot_obj = Plot(study,observations)
# ----> 5 plot_obj.plot()
#
# ~/Downloads/testProjs/MSC_M/calibration_osteogenesis.py in plot(self)
#      77                         x_labels = [item.get_text() for item in ax.get_xticklabels()]
#      78                         ax.set_xticks(ticks = [int(i) for i in range(len(self.observations[self.study]['IDs']))])
# ---> 79                         ax.set_xticklabels(self.adjust_x_label(self.observations[self.study]['IDs']))
#      80                 #     ax.get_yaxis().set_major_formatter(
#      81                 #         matplotlib.ticker.FuncFormatter(lambda x, p: format(int(x)/1000, ',')))
#
# ~/Downloads/testProjs/MSC_M/calibration_osteogenesis.py in adjust_x_label(self, labels)
#     126                                 adj_labels.append('100')
#     127                         else:
# --> 128                                 raise('not defined')
#     129                 return adj_labels
#     130
#
# TypeError: exceptions must derive from BaseException
